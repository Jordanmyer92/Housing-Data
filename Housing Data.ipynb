# %%
import requests
import pandas as pd
import json
import openpyxl
import xlsxwriter

# %%
url = "https://data.kcmo.org/resource/2ebw-sp7f.json"

landbank_response = requests.get(url)

# %%
#print(landbank_response)

# %%
landbank_json = landbank_response.json()

#print(type(landbank_json))

# %%
landbank_df = pd.DataFrame(landbank_json)

#landbank_df.columns

# %%
landbank_df =landbank_df[["property_status", "address", "neighborhood", "sold_date", "property_condition", "number_of_bedrooms", "date_evaluated"]]

#landbank_df["neighborhood"].values

# %%
url = "https://data.kcmo.org/resource/ax3m-jhxx.json"

danger_response = requests.get(url)

# %%
danger_json = danger_response.json()

# %%
danger_df = pd.DataFrame(danger_json)

#danger_df.columns

# %%
danger_df =danger_df[["address", "case_opened", "zip_code", "statusofcase"]]

# %%
url = "https://data.kcmo.org/resource/6hy4-5b3m.json"

llc_response = requests.get(url)

# %%
llc_json = llc_response.json()

# %%
llc_df = pd.DataFrame(llc_json)

#llc_df.columns

# %%
#llc_df =llc_df[["llc_name", "address", "state", "applicant_name", "does_business_as"]]

# %%
url = "https://data.kcmo.org/resource/jf4z-cm5s.json"

codes_response = requests.get(url)

# %%
codes_json = codes_response.json()

# %%
codes_df = pd.DataFrame(codes_json)

#codes_df.columns

# %%
codes_df = codes_df[["address", "violation_description", "case_opened", "violation_entry_date", "status", "neighborhood"]]

#codes_df

# %%
#LIST OF CODES VIOLATIONS

codes_list = codes_df[codes_df["violation_entry_date"] > "2021"]
Wendell_Phillips = codes_list[codes_df["neighborhood"] == "Wendell Phillips"]

Wendell_Phillips
# Out:
# C:\Users\jorda\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                address                     violation_description  \
# 43     1720 E 24th Ter                        UNAPPROVED STORAGE
# 44     1720 E 24th Ter        LITTER, TRASH, REFUSE, AND RUBBISH
# 45     1720 E 24th Ter                        UNAPPROVED PARKING
# 46     1720 E 24th Ter     PAINTING NEEDED ON EXTERIOR WALL TRIM
# 47     1720 E 24th Ter  ALL FENCES AND RET. WALLS KEPT IN REPAIR
# 48     1720 E 24th Ter         DOWNSPOUT DISCONNECTED OR MISSING
# 49     1720 E 24th Ter   SOFFIT BOARDS (EAVES) ARE LOOSE/MISSING
# 50     1720 E 24th Ter                                RANK WEEDS
# 77   2540 Michigan Ave   EXTERIOR SURFACE MATERIAL NOT PROTECTED
# 78   2540 Michigan Ave                    EAVES ARE IN DISREPAIR
# ...

# %%
#LIST OF OUT OF STATE OWNERS

llc_list = llc_df[llc_df["state"] == "AZ"]

llc_list
# Out:
#                         llc_name                                  address  \
# 26                  DJ Props LLC                            7531 E 2nd St
# 157  Reel Estate Development LLC            4041 N. Central Ave, Ste 1200
# 348    Gridlock Investments, LLC                         4620 E Culver St
# 387           Warwick Associates                       23226 West Watkins
# 417    Shipley Building, LLC The                     5002 E Sierra Sunset
# 616              Allied Services  15880 N Greenway-Hayden Loop, Suite 100
# 686              W&B Investments                        5808 E 2nd Street
# 871         A24Z Investments LLC                  2030 E Broadway St. #22
# 881   Bar Investment Fund 3, LLC                     2030 E. Broadway #22
#
#            city state zipcode      applicant_name does_business_as
# 26   Scottsdale    AZ   85251       Dean Graziosi              NaN
# 157     Phoenix    AZ   85012                 NaN              NaN
# ...

# %%
#LANDBANK LIST OF HOUSES

housing_list = landbank_df[landbank_df["number_of_bedrooms"] == "3"]
housing_list_2 = housing_list[landbank_df["property_status"] == "Acquired"]

housing_list_2
# Out:
# C:\Users\jorda\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#     property_status                 address  \
# 50         Acquired        3314 College Ave
# 320        Acquired          3508 E 36TH ST
# 441        Acquired         3910 E 58TH TER
# 452        Acquired          3017 E 60TH ST
# 844        Acquired  4024 Bellefontaine Ave
#
#                               neighborhood                sold_date  \
# 50                      Oak Park Northwest  2017-09-27T00:00:00.000
# 320  Palestine West And Oak Park Northeast                      NaN
# 441                  Swope Parkway-Elmwood                      NaN
# 452                  South Town Fork Creek                      NaN
# 844                     Oak Park Southwest                      NaN
#
#                   property_condition number_of_bedrooms  \
# ...

# %%
#DANGEROUS BUILDINGS LIST

#danger_list = danger_df[danger_df["address"] == "Indiana"]
danger_list_2 = danger_df[danger_df["zip_code"] == "64128"]

danger_list_2
# Out:
#                     address              case_opened zip_code  \
# 13       3417 Cleveland Ave  2021-04-23T00:00:00.000    64128
# 15         3640 Elmwood Ave  2013-07-16T00:00:00.000    64128
# 25          3329 Spruce Ave  2021-02-03T00:00:00.000    64128
# 37          5630 E 29th Ter  2017-10-30T00:00:00.000    64128
# 38           4805 E 37TH ST  2021-03-25T00:00:00.000    64128
# 47          5401 E 27TH TER  2021-01-26T00:00:00.000    64128
# 49           5434 E 28th St  2020-10-29T00:00:00.000    64128
# 58          2911 Monroe Ave  2019-10-07T00:00:00.000    64128
# 59          2823 Wabash Ave  2020-02-04T00:00:00.000    64128
# 66         3024 Indiana Ave  2021-05-06T00:00:00.000    64128
# 67           3335 Bales Ave  2020-05-27T00:00:00.000    64128
# 68         3333 Benton Blvd  2020-11-19T00:00:00.000    64128
# 77           5440 E 28TH ST  2019-10-11T00:00:00.000    64128
# 88   3518 Bellefontaine Ave  2019-12-10T00:00:00.000    64128
# ...

# %%
# determining the name of the file
file_name = "Wendell_Phillips.xlsx"
  
# saving the excel
Wendell_Phillips.to_excel(file_name)
print('DataFrame is written to Excel File successfully.')
# Out:
# DataFrame is written to Excel File successfully.
